# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder, RobustScaler
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, log_loss
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import os
import datetime

# %%
# Step 1: Data Loading with the correct delimiter
file_path = r"C:\Users\Canela\Desktop\Project\CTU-IoT-Malware-Capture-60-1\bro\conn.log.labeled.csv"

df = pd.read_csv(file_path, delimiter='\t', comment='#', na_values='-', header=None, dtype={'service': str})

# Manually assign column names based on the expected structure
df.columns = [
    'ts', 'uid', 'id.orig_h', 'id.orig_p', 'id.resp_h', 'id.resp_p', 'proto', 'service',
    'duration', 'orig_bytes', 'resp_bytes', 'conn_state', 'local_orig', 'local_resp',
    'missed_bytes', 'history', 'orig_pkts', 'orig_ip_bytes', 'resp_pkts', 'resp_ip_bytes',
    'label'
]

# Check the unique values in the 'label' column
print("Final unique labels:")
print(df['label'].unique())
print("Number of unique labels:", len(df['label'].unique()))
# Out:
# C:\Users\Canela\AppData\Local\Temp\ipykernel_40780\3440588175.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter='\t', comment='#', na_values='-', header=None, dtype={'service': str})
# Final unique labels:
# ['-   Benign   -' '-   Malicious   C&C-HeartBeat' '-   Malicious   DDoS']
# Number of unique labels: 3

# %%
# Step 2: Handle Categorical Variables and Feature Engineering
# Encode label
label_encoder = LabelEncoder()
df['label_encoded'] = label_encoder.fit_transform(df['label'])

# Drop columns that might cause data leakage
df.drop(columns=['uid', 'ts', 'id.orig_h', 'id.resp_h'], inplace=True)

# One-Hot Encode categorical variables
categorical_features = ['proto', 'service', 'conn_state', 'local_orig', 'local_resp', 'history']
df = pd.get_dummies(df, columns=categorical_features, drop_first=True)

# Fill remaining NaN values if any
df.fillna(0, inplace=True)

# Split features and target
X = df.drop(['label', 'label_encoded'], axis=1)
y = df['label_encoded']

# %%
# Step 3: Handle Imbalance using SMOTE
smote = SMOTE()
X_res, y_res = smote.fit_resample(X, y)

# %%
# Step 4: Scale Features
scaler = RobustScaler()
X_res_scaled = scaler.fit_transform(X_res)

# %%
# Step 5: Stratified K-Fold Cross-Validation Setup
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cross_val_scores = []
roc_auc_scores = []
log_losses = []

# Model training and evaluation within each fold
for train_index, val_index in skf.split(X_res_scaled, y_res):
    X_train, X_val = X_res_scaled[train_index], X_res_scaled[val_index]
    y_train, y_val = y_res[train_index], y_res[val_index]

    # Compute class weights
    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
    class_weights_dict = dict(enumerate(class_weights))

    # Step 6: Build and Compile Model
    model = Sequential([
        Flatten(input_shape=(X_train.shape[1],)),
        Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
        Dropout(0.4),
        Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
        Dropout(0.3),
        Dense(len(np.unique(y_res)), activation='softmax')
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Setup callbacks for early stopping and tensorboard
    log_dir = os.path.join("train_logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
    tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
    early_stop_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Step 7: Model Training
    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=256,
              class_weight=class_weights_dict, callbacks=[tensorboard_callback, early_stop_callback])

    # Step 8: Model Evaluation
    val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=2)
    val_predictions = model.predict(X_val)
    y_pred_classes = np.argmax(val_predictions, axis=1)

    cross_val_scores.append(val_accuracy)
    roc_auc_scores.append(roc_auc_score(y_val, val_predictions, multi_class='ovo'))
    log_losses.append(log_loss(y_val, val_predictions))

    print("Confusion Matrix:")
    print(confusion_matrix(y_val, y_pred_classes))
    print("Classification Report:")
    print(classification_report(y_val, y_pred_classes, target_names=label_encoder.classes_))
# Out:
# Epoch 1/50
# 33549/33549 [==============================] - 69s 2ms/step - loss: 5.4140 - accuracy: 0.9993 - val_loss: 1.2944 - val_accuracy: 1.0000
# Epoch 2/50
# 33549/33549 [==============================] - 66s 2ms/step - loss: 2.9457 - accuracy: 0.9998 - val_loss: 0.2367 - val_accuracy: 1.0000
# Epoch 3/50
# 33549/33549 [==============================] - 67s 2ms/step - loss: 2.8399 - accuracy: 0.9998 - val_loss: 2.3149 - val_accuracy: 1.0000
# Epoch 4/50
# 33549/33549 [==============================] - 68s 2ms/step - loss: 5.0217 - accuracy: 0.9998 - val_loss: 0.0096 - val_accuracy: 0.9992
# Epoch 5/50
# 33549/33549 [==============================] - 67s 2ms/step - loss: 2.3035 - accuracy: 0.9997 - val_loss: 1.5230 - val_accuracy: 1.0000
# Epoch 6/50
# 33549/33549 [==============================] - 68s 2ms/step - loss: 1.3273 - accuracy: 0.9998 - val_loss: 1.9090 - val_accuracy: 1.0000
# Epoch 7/50
# 33549/33549 [==============================] - 67s 2ms/step - loss: 1.3018 - accuracy: 0.9997 - val_loss: 0.5004 - val_accuracy: 1.0000
# Epoch 8/50
# 33549/33549 [==============================] - 68s 2ms/step - loss: 2.6845 - accuracy: 0.9997 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 9/50
# 33549/33549 [==============================] - 68s 2ms/step - loss: 1.6136 - accuracy: 0.9997 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 10/50
# 33549/33549 [==============================] - 68s 2ms/step - loss: 1.5524 - accuracy: 0.9998 - val_loss: 0.1197 - val_accuracy: 1.0000
# Epoch 11/50
# 33549/33549 [==============================] - 67s 2ms/step - loss: 1.5090 - accuracy: 0.9998 - val_loss: 0.2499 - val_accuracy: 1.0000
# Epoch 12/50
# 33549/33549 [==============================] - 68s 2ms/step - loss: 1.4187 - accuracy: 0.9998 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 13/50
# 33549/33549 [==============================] - 68s 2ms/step - loss: 1.3172 - accuracy: 0.9998 - val_loss: 0.6884 - val_accuracy: 1.0000
# Epoch 14/50
# 33549/33549 [==============================] - 67s 2ms/step - loss: 3.3596 - accuracy: 0.9998 - val_loss: 0.0326 - val_accuracy: 1.0000
# Epoch 15/50
# 33549/33549 [==============================] - 68s 2ms/step - loss: 3.7632 - accuracy: 0.9998 - val_loss: 0.1774 - val_accuracy: 1.0000
# Epoch 16/50
# 33549/33549 [==============================] - 67s 2ms/step - loss: 3.7302 - accuracy: 0.9998 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 17/50
# 33549/33549 [==============================] - 67s 2ms/step - loss: 2.7709 - accuracy: 0.9998 - val_loss: 0.6346 - val_accuracy: 1.0000
# Epoch 18/50
# 33549/33549 [==============================] - 68s 2ms/step - loss: 4.7090 - accuracy: 0.9998 - val_loss: 0.4980 - val_accuracy: 1.0000
# Epoch 19/50
# 33549/33549 [==============================] - 67s 2ms/step - loss: 4.0234 - accuracy: 0.9999 - val_loss: 2.8394 - val_accuracy: 1.0000
# 67097/67097 - 38s - loss: 0.0073 - accuracy: 1.0000 - 38s/epoch - 567us/step
# 67097/67097 [==============================] - 40s 597us/step
# Confusion Matrix:
# [[715692      0      0]
#  [     0 715691      0]
#  [    15      0 715677]]
# Classification Report:
#                                precision    recall  f1-score   support
#
#                -   Benign   -       1.00      1.00      1.00    715692
# -   Malicious   C&C-HeartBeat       1.00      1.00      1.00    715691
#          -   Malicious   DDoS       1.00      1.00      1.00    715692
#
#                      accuracy                           1.00   2147075
#                     macro avg       1.00      1.00      1.00   2147075
#                  weighted avg       1.00      1.00      1.00   2147075
#
# Epoch 1/50
# 33549/33549 [==============================] - 83s 2ms/step - loss: 5.2382 - accuracy: 0.9993 - val_loss: 2.7296 - val_accuracy: 1.0000
# Epoch 2/50
# 33549/33549 [==============================] - 81s 2ms/step - loss: 4.4918 - accuracy: 0.9998 - val_loss: 0.4280 - val_accuracy: 1.0000
# Epoch 3/50
# 33549/33549 [==============================] - 83s 2ms/step - loss: 3.1501 - accuracy: 0.9999 - val_loss: 0.5447 - val_accuracy: 1.0000
# Epoch 4/50
# 33549/33549 [==============================] - 82s 2ms/step - loss: 5.4902 - accuracy: 0.9998 - val_loss: 1.7335 - val_accuracy: 1.0000
# Epoch 5/50
# 33549/33549 [==============================] - 83s 2ms/step - loss: 2.1049 - accuracy: 0.9998 - val_loss: 0.4031 - val_accuracy: 1.0000
# Epoch 6/50
# 33549/33549 [==============================] - 82s 2ms/step - loss: 5.2056 - accuracy: 0.9998 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 7/50
# 33549/33549 [==============================] - 83s 2ms/step - loss: 6.3504 - accuracy: 0.9998 - val_loss: 1.9930 - val_accuracy: 1.0000
# Epoch 8/50
# 33549/33549 [==============================] - 93s 3ms/step - loss: 7.5329 - accuracy: 0.9998 - val_loss: 1.7729 - val_accuracy: 1.0000
# Epoch 9/50
# 33549/33549 [==============================] - 96s 3ms/step - loss: 11.3525 - accuracy: 0.9998 - val_loss: 1.0012 - val_accuracy: 1.0000
# Epoch 10/50
# 33549/33549 [==============================] - 107s 3ms/step - loss: 4.6066 - accuracy: 0.9998 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 11/50
# 33549/33549 [==============================] - 108s 3ms/step - loss: 2.2491 - accuracy: 0.9998 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 12/50
# 33549/33549 [==============================] - 109s 3ms/step - loss: 3.2218 - accuracy: 0.9998 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 13/50
# 33549/33549 [==============================] - 97s 3ms/step - loss: 16.1407 - accuracy: 0.9998 - val_loss: 0.6154 - val_accuracy: 1.0000
# Epoch 14/50
# 33549/33549 [==============================] - 95s 3ms/step - loss: 5.7761 - accuracy: 0.9998 - val_loss: 0.7555 - val_accuracy: 1.0000
# Epoch 15/50
# 33549/33549 [==============================] - 91s 3ms/step - loss: 5.1338 - accuracy: 0.9997 - val_loss: 1.0230 - val_accuracy: 1.0000
# Epoch 16/50
# 33549/33549 [==============================] - 88s 3ms/step - loss: 2.6348 - accuracy: 0.9997 - val_loss: 0.2113 - val_accuracy: 1.0000
# Epoch 17/50
# 33549/33549 [==============================] - 91s 3ms/step - loss: 1.5768 - accuracy: 0.9997 - val_loss: 0.2340 - val_accuracy: 1.0000
# Epoch 18/50
# 33549/33549 [==============================] - 90s 3ms/step - loss: 1.2387 - accuracy: 0.9995 - val_loss: 0.2345 - val_accuracy: 1.0000
# Epoch 19/50
# 33549/33549 [==============================] - 90s 3ms/step - loss: 0.4176 - accuracy: 0.9993 - val_loss: 0.6420 - val_accuracy: 1.0000
# Epoch 20/50
# 33549/33549 [==============================] - 84s 3ms/step - loss: 1.4545 - accuracy: 0.9994 - val_loss: 0.0068 - val_accuracy: 0.9992
# Epoch 21/50
# 33549/33549 [==============================] - 85s 3ms/step - loss: 0.5074 - accuracy: 0.9992 - val_loss: 0.0067 - val_accuracy: 0.9992
# 67097/67097 - 40s - loss: 0.0063 - accuracy: 1.0000 - 40s/epoch - 591us/step
# 67097/67097 [==============================] - 41s 609us/step
# Confusion Matrix:
# [[715692      0      0]
#  [     0 715691      0]
#  [     6      0 715685]]
# Classification Report:
#                                precision    recall  f1-score   support
#
#                -   Benign   -       1.00      1.00      1.00    715692
# -   Malicious   C&C-HeartBeat       1.00      1.00      1.00    715691
#          -   Malicious   DDoS       1.00      1.00      1.00    715691
#
#                      accuracy                           1.00   2147074
#                     macro avg       1.00      1.00      1.00   2147074
#                  weighted avg       1.00      1.00      1.00   2147074
#
# Epoch 1/50
# 33549/33549 [==============================] - 102s 3ms/step - loss: 4.3093 - accuracy: 0.9993 - val_loss: 1.4636 - val_accuracy: 1.0000
# Epoch 2/50
# 33549/33549 [==============================] - 96s 3ms/step - loss: 2.9603 - accuracy: 0.9999 - val_loss: 1.1343 - val_accuracy: 1.0000
# Epoch 3/50
# 33549/33549 [==============================] - 91s 3ms/step - loss: 1.8458 - accuracy: 0.9999 - val_loss: 8.0022 - val_accuracy: 1.0000
# Epoch 4/50
# 33549/33549 [==============================] - 91s 3ms/step - loss: 2.7929 - accuracy: 0.9998 - val_loss: 6.1708 - val_accuracy: 1.0000
# Epoch 5/50
# 33549/33549 [==============================] - 90s 3ms/step - loss: 5.5298 - accuracy: 0.9998 - val_loss: 29.3018 - val_accuracy: 1.0000
# Epoch 6/50
# 33549/33549 [==============================] - 90s 3ms/step - loss: 8.3311 - accuracy: 0.9999 - val_loss: 3.3197 - val_accuracy: 1.0000
# Epoch 7/50
# 33549/33549 [==============================] - 91s 3ms/step - loss: 15.1478 - accuracy: 0.9998 - val_loss: 15.6726 - val_accuracy: 1.0000
# Epoch 8/50
# 33549/33549 [==============================] - 96s 3ms/step - loss: 6.7772 - accuracy: 0.9999 - val_loss: 8.2419 - val_accuracy: 1.0000
# Epoch 9/50
# 33549/33549 [==============================] - 122s 4ms/step - loss: 3.8234 - accuracy: 0.9998 - val_loss: 1.3970 - val_accuracy: 1.0000
# Epoch 10/50
# 33549/33549 [==============================] - 121s 4ms/step - loss: 9.0043 - accuracy: 0.9998 - val_loss: 0.0416 - val_accuracy: 1.0000
# Epoch 11/50
# 33549/33549 [==============================] - 120s 4ms/step - loss: 3.3830 - accuracy: 0.9997 - val_loss: 2.9979 - val_accuracy: 1.0000
# Epoch 12/50
# 33549/33549 [==============================] - 112s 3ms/step - loss: 1.1954 - accuracy: 0.9998 - val_loss: 0.9421 - val_accuracy: 1.0000
# Epoch 13/50
# 33549/33549 [==============================] - 110s 3ms/step - loss: 1.4222 - accuracy: 0.9995 - val_loss: 7.0345 - val_accuracy: 1.0000
# Epoch 14/50
# 33549/33549 [==============================] - 108s 3ms/step - loss: 1.4096 - accuracy: 0.9994 - val_loss: 1.8559 - val_accuracy: 1.0000
# Epoch 15/50
# 33549/33549 [==============================] - 109s 3ms/step - loss: 0.3054 - accuracy: 0.9995 - val_loss: 0.0072 - val_accuracy: 0.9992
# Epoch 16/50
# 33549/33549 [==============================] - 108s 3ms/step - loss: 0.5768 - accuracy: 0.9995 - val_loss: 2.0310 - val_accuracy: 1.0000
# Epoch 17/50
# 33549/33549 [==============================] - 108s 3ms/step - loss: 0.3706 - accuracy: 0.9994 - val_loss: 0.0072 - val_accuracy: 0.9992
# Epoch 18/50
# 33549/33549 [==============================] - 108s 3ms/step - loss: 0.4768 - accuracy: 0.9993 - val_loss: 0.5305 - val_accuracy: 0.9994
# Epoch 19/50
# 33549/33549 [==============================] - 108s 3ms/step - loss: 0.4169 - accuracy: 0.9989 - val_loss: 0.0073 - val_accuracy: 0.9992
# Epoch 20/50
# 33549/33549 [==============================] - 108s 3ms/step - loss: 0.3178 - accuracy: 0.9993 - val_loss: 14.7667 - val_accuracy: 1.0000
# Epoch 21/50
# 33549/33549 [==============================] - 109s 3ms/step - loss: 1.9176 - accuracy: 0.9995 - val_loss: 0.0075 - val_accuracy: 0.9992
# Epoch 22/50
# 33549/33549 [==============================] - 110s 3ms/step - loss: 0.5509 - accuracy: 0.9993 - val_loss: 0.8510 - val_accuracy: 1.0000
# Epoch 23/50
# 33549/33549 [==============================] - 109s 3ms/step - loss: 0.6162 - accuracy: 0.9994 - val_loss: 0.1865 - val_accuracy: 0.9995
# Epoch 24/50
# 33549/33549 [==============================] - 110s 3ms/step - loss: 0.4007 - accuracy: 0.9993 - val_loss: 0.3790 - val_accuracy: 0.9995
# Epoch 25/50
# 33549/33549 [==============================] - 109s 3ms/step - loss: 0.2526 - accuracy: 0.9993 - val_loss: 1.1454 - val_accuracy: 1.0000
# Epoch 26/50
# 33549/33549 [==============================] - 109s 3ms/step - loss: 0.5183 - accuracy: 0.9994 - val_loss: 10.0422 - val_accuracy: 1.0000
# Epoch 27/50
# 33549/33549 [==============================] - 110s 3ms/step - loss: 1.7300 - accuracy: 0.9995 - val_loss: 6.3499 - val_accuracy: 1.0000
# 67097/67097 - 47s - loss: 0.0072 - accuracy: 0.9992 - 47s/epoch - 697us/step
# 67097/67097 [==============================] - 49s 725us/step
# Confusion Matrix:
# [[713946   1745      0]
#  [     0 715692      0]
#  [     9      6 715676]]
# Classification Report:
#                                precision    recall  f1-score   support
#
#                -   Benign   -       1.00      1.00      1.00    715691
# -   Malicious   C&C-HeartBeat       1.00      1.00      1.00    715692
#          -   Malicious   DDoS       1.00      1.00      1.00    715691
#
#                      accuracy                           1.00   2147074
#                     macro avg       1.00      1.00      1.00   2147074
#                  weighted avg       1.00      1.00      1.00   2147074
#
# Epoch 1/50
# 33549/33549 [==============================] - 116s 3ms/step - loss: 10.1594 - accuracy: 0.9994 - val_loss: 0.2318 - val_accuracy: 1.0000
# Epoch 2/50
# 33549/33549 [==============================] - 109s 3ms/step - loss: 2.6087 - accuracy: 0.9999 - val_loss: 0.0834 - val_accuracy: 1.0000
# Epoch 3/50
# 33549/33549 [==============================] - 109s 3ms/step - loss: 1.6840 - accuracy: 0.9999 - val_loss: 0.1081 - val_accuracy: 1.0000
# Epoch 4/50
# 33549/33549 [==============================] - 109s 3ms/step - loss: 1.5691 - accuracy: 0.9999 - val_loss: 0.2020 - val_accuracy: 1.0000
# Epoch 5/50
# 33549/33549 [==============================] - 109s 3ms/step - loss: 8.5277 - accuracy: 0.9998 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 6/50
# 33549/33549 [==============================] - 105s 3ms/step - loss: 4.1673 - accuracy: 0.9997 - val_loss: 0.0413 - val_accuracy: 1.0000
# Epoch 7/50
# 33549/33549 [==============================] - 116s 3ms/step - loss: 2.5608 - accuracy: 0.9998 - val_loss: 2.8215 - val_accuracy: 1.0000
# Epoch 8/50
# 33549/33549 [==============================] - 114s 3ms/step - loss: 9.3730 - accuracy: 0.9998 - val_loss: 0.1654 - val_accuracy: 1.0000
# Epoch 9/50
# 33549/33549 [==============================] - 98s 3ms/step - loss: 9.8613 - accuracy: 0.9997 - val_loss: 3.5472 - val_accuracy: 1.0000
# Epoch 10/50
# 33549/33549 [==============================] - 79s 2ms/step - loss: 6.1818 - accuracy: 0.9998 - val_loss: 13.6913 - val_accuracy: 1.0000
# Epoch 11/50
# 33549/33549 [==============================] - 80s 2ms/step - loss: 19.0920 - accuracy: 0.9998 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 12/50
# 33549/33549 [==============================] - 78s 2ms/step - loss: 4.9034 - accuracy: 0.9998 - val_loss: 2.2973 - val_accuracy: 1.0000
# Epoch 13/50
# 33549/33549 [==============================] - 78s 2ms/step - loss: 5.0645 - accuracy: 0.9998 - val_loss: 0.0059 - val_accuracy: 1.0000
# Epoch 14/50
# 33549/33549 [==============================] - 78s 2ms/step - loss: 5.5543 - accuracy: 0.9998 - val_loss: 1.0603 - val_accuracy: 1.0000
# Epoch 15/50
# 33549/33549 [==============================] - 78s 2ms/step - loss: 4.5382 - accuracy: 0.9998 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 16/50
# 33549/33549 [==============================] - 78s 2ms/step - loss: 10.3273 - accuracy: 0.9997 - val_loss: 0.4877 - val_accuracy: 1.0000
# Epoch 17/50
# 33549/33549 [==============================] - 77s 2ms/step - loss: 9.2475 - accuracy: 0.9997 - val_loss: 0.0235 - val_accuracy: 1.0000
# Epoch 18/50
# 33549/33549 [==============================] - 78s 2ms/step - loss: 10.5908 - accuracy: 0.9998 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 19/50
# 33549/33549 [==============================] - 78s 2ms/step - loss: 2.2087 - accuracy: 0.9998 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 20/50
# 33549/33549 [==============================] - 81s 2ms/step - loss: 8.3797 - accuracy: 0.9998 - val_loss: 0.2219 - val_accuracy: 1.0000
# Epoch 21/50
# 33549/33549 [==============================] - 78s 2ms/step - loss: 1.8609 - accuracy: 0.9998 - val_loss: 0.1818 - val_accuracy: 1.0000
# Epoch 22/50
# 33549/33549 [==============================] - 78s 2ms/step - loss: 0.7703 - accuracy: 0.9995 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 23/50
# 33549/33549 [==============================] - 77s 2ms/step - loss: 0.6378 - accuracy: 0.9996 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 24/50
# 33549/33549 [==============================] - 78s 2ms/step - loss: 1.0988 - accuracy: 0.9994 - val_loss: 0.1542 - val_accuracy: 1.0000
# Epoch 25/50
# 33549/33549 [==============================] - 78s 2ms/step - loss: 1.6141 - accuracy: 0.9989 - val_loss: 1.1327 - val_accuracy: 1.0000
# Epoch 26/50
# 33549/33549 [==============================] - 78s 2ms/step - loss: 3.7157 - accuracy: 0.9994 - val_loss: 0.0318 - val_accuracy: 1.0000
# Epoch 27/50
# 33549/33549 [==============================] - 77s 2ms/step - loss: 0.7218 - accuracy: 0.9991 - val_loss: 0.0069 - val_accuracy: 0.9992
# Epoch 28/50
# 33549/33549 [==============================] - 77s 2ms/step - loss: 0.4123 - accuracy: 0.9993 - val_loss: 0.2500 - val_accuracy: 1.0000
# Epoch 29/50
# 33549/33549 [==============================] - 78s 2ms/step - loss: 4.0773 - accuracy: 0.9992 - val_loss: 0.0077 - val_accuracy: 0.9992
# Epoch 30/50
# 33549/33549 [==============================] - 77s 2ms/step - loss: 0.5283 - accuracy: 0.9994 - val_loss: 0.7790 - val_accuracy: 1.0000
# Epoch 31/50
# 33549/33549 [==============================] - 77s 2ms/step - loss: 2.7950 - accuracy: 0.9993 - val_loss: 0.0068 - val_accuracy: 0.9992
# Epoch 32/50
# 33549/33549 [==============================] - 77s 2ms/step - loss: 1.2630 - accuracy: 0.9992 - val_loss: 0.0089 - val_accuracy: 0.9996
# 67097/67097 - 38s - loss: 0.0023 - accuracy: 1.0000 - 38s/epoch - 569us/step
# 67097/67097 [==============================] - 41s 614us/step
# Confusion Matrix:
# [[715691      0      0]
#  [     0 715692      0]
#  [    12      0 715679]]
# Classification Report:
#                                precision    recall  f1-score   support
#
#                -   Benign   -       1.00      1.00      1.00    715691
# -   Malicious   C&C-HeartBeat       1.00      1.00      1.00    715692
#          -   Malicious   DDoS       1.00      1.00      1.00    715691
#
#                      accuracy                           1.00   2147074
#                     macro avg       1.00      1.00      1.00   2147074
#                  weighted avg       1.00      1.00      1.00   2147074
#
# Epoch 1/50
# 33549/33549 [==============================] - 83s 2ms/step - loss: 7.4993 - accuracy: 0.9994 - val_loss: 12.3588 - val_accuracy: 1.0000
# Epoch 2/50
# 33549/33549 [==============================] - 81s 2ms/step - loss: 4.1754 - accuracy: 0.9999 - val_loss: 7.6909 - val_accuracy: 1.0000
# Epoch 3/50
# 33549/33549 [==============================] - 91s 3ms/step - loss: 5.1769 - accuracy: 0.9998 - val_loss: 2.8868 - val_accuracy: 1.0000
# Epoch 4/50
# 33549/33549 [==============================] - 90s 3ms/step - loss: 5.7035 - accuracy: 0.9999 - val_loss: 8.3910 - val_accuracy: 1.0000
# Epoch 5/50
# 33549/33549 [==============================] - 90s 3ms/step - loss: 9.9449 - accuracy: 0.9999 - val_loss: 1.8362 - val_accuracy: 1.0000
# Epoch 6/50
# 33549/33549 [==============================] - 89s 3ms/step - loss: 7.6017 - accuracy: 0.9999 - val_loss: 1.0093 - val_accuracy: 1.0000
# Epoch 7/50
# 33549/33549 [==============================] - 90s 3ms/step - loss: 2.2471 - accuracy: 0.9999 - val_loss: 10.5284 - val_accuracy: 1.0000
# Epoch 8/50
# 33549/33549 [==============================] - 91s 3ms/step - loss: 5.0977 - accuracy: 0.9999 - val_loss: 5.2579 - val_accuracy: 1.0000
# Epoch 9/50
# 33549/33549 [==============================] - 90s 3ms/step - loss: 2.2946 - accuracy: 0.9998 - val_loss: 0.2665 - val_accuracy: 1.0000
# Epoch 10/50
# 33549/33549 [==============================] - 90s 3ms/step - loss: 2.6952 - accuracy: 0.9998 - val_loss: 0.4771 - val_accuracy: 1.0000
# Epoch 11/50
# 33549/33549 [==============================] - 91s 3ms/step - loss: 0.5518 - accuracy: 0.9998 - val_loss: 0.0836 - val_accuracy: 1.0000
# Epoch 12/50
# 33549/33549 [==============================] - 89s 3ms/step - loss: 0.8878 - accuracy: 0.9995 - val_loss: 0.0100 - val_accuracy: 0.9993
# Epoch 13/50
# 33549/33549 [==============================] - 94s 3ms/step - loss: 0.1419 - accuracy: 0.9994 - val_loss: 0.0079 - val_accuracy: 0.9992
# Epoch 14/50
# 33549/33549 [==============================] - 91s 3ms/step - loss: 0.2664 - accuracy: 0.9993 - val_loss: 0.0071 - val_accuracy: 0.9992
# Epoch 15/50
# 33549/33549 [==============================] - 89s 3ms/step - loss: 0.4341 - accuracy: 0.9992 - val_loss: 0.0103 - val_accuracy: 0.9994
# Epoch 16/50
# 33549/33549 [==============================] - 90s 3ms/step - loss: 0.3636 - accuracy: 0.9992 - val_loss: 0.1767 - val_accuracy: 1.0000
# Epoch 17/50
# 33549/33549 [==============================] - 89s 3ms/step - loss: 0.2598 - accuracy: 0.9993 - val_loss: 2.9991 - val_accuracy: 1.0000
# Epoch 18/50
# 33549/33549 [==============================] - 89s 3ms/step - loss: 0.0973 - accuracy: 0.9995 - val_loss: 0.8405 - val_accuracy: 1.0000
# Epoch 19/50
# 33549/33549 [==============================] - 90s 3ms/step - loss: 0.2279 - accuracy: 0.9993 - val_loss: 0.0065 - val_accuracy: 0.9992
# Epoch 20/50
# 33549/33549 [==============================] - 89s 3ms/step - loss: 0.1306 - accuracy: 0.9993 - val_loss: 0.0080 - val_accuracy: 0.9992
# Epoch 21/50
# 33549/33549 [==============================] - 90s 3ms/step - loss: 0.2451 - accuracy: 0.9992 - val_loss: 0.0073 - val_accuracy: 0.9992
# Epoch 22/50
# 33549/33549 [==============================] - 90s 3ms/step - loss: 0.3474 - accuracy: 0.9992 - val_loss: 0.0073 - val_accuracy: 0.9992
# Epoch 23/50
# 33549/33549 [==============================] - 89s 3ms/step - loss: 0.0631 - accuracy: 0.9992 - val_loss: 2.4704 - val_accuracy: 1.0000
# Epoch 24/50
# 33549/33549 [==============================] - 89s 3ms/step - loss: 0.1772 - accuracy: 0.9993 - val_loss: 0.0073 - val_accuracy: 0.9992
# Epoch 25/50
# 33549/33549 [==============================] - 90s 3ms/step - loss: 0.9597 - accuracy: 0.9991 - val_loss: 0.0075 - val_accuracy: 0.9992
# Epoch 26/50
# 33549/33549 [==============================] - 89s 3ms/step - loss: 0.3147 - accuracy: 0.9991 - val_loss: 0.0075 - val_accuracy: 0.9992
# Epoch 27/50
# 33549/33549 [==============================] - 89s 3ms/step - loss: 0.4727 - accuracy: 0.9993 - val_loss: 0.0074 - val_accuracy: 0.9992
# Epoch 28/50
# 33549/33549 [==============================] - 90s 3ms/step - loss: 0.5092 - accuracy: 0.9993 - val_loss: 0.9373 - val_accuracy: 1.0000
# Epoch 29/50
# 33549/33549 [==============================] - 90s 3ms/step - loss: 0.1645 - accuracy: 0.9993 - val_loss: 0.4316 - val_accuracy: 1.0000
# 67097/67097 - 44s - loss: 0.0065 - accuracy: 0.9992 - 44s/epoch - 653us/step
# 67097/67097 [==============================] - 45s 663us/step
# Confusion Matrix:
# [[713963   1728      0]
#  [     0 715691      0]
#  [    10      8 715674]]
# Classification Report:
#                                precision    recall  f1-score   support
#
#                -   Benign   -       1.00      1.00      1.00    715691
# -   Malicious   C&C-HeartBeat       1.00      1.00      1.00    715691
#          -   Malicious   DDoS       1.00      1.00      1.00    715692
#
#                      accuracy                           1.00   2147074
#                     macro avg       1.00      1.00      1.00   2147074
#                  weighted avg       1.00      1.00      1.00   2147074

# %%
# Step 9: Summary of Cross-Validation Results
print(f"Mean CV Accuracy: {np.mean(cross_val_scores)}")
print(f"Mean ROC-AUC Score: {np.mean(roc_auc_scores)}")
print(f"Mean Log Loss: {np.mean(log_losses)}")
# Out:
# Mean CV Accuracy: 0.9996703386306762
# Mean ROC-AUC Score: 0.9999452812378286
# Mean Log Loss: 0.00229968900853154
