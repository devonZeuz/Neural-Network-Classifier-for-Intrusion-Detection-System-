# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder, RobustScaler
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, log_loss
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import os
import datetime

# %%
# Step 1: Data Loading with the correct delimiter
file_path = r"C:\Users\Canela\Desktop\Project\CTU-IoT-Malware-Capture-34-1\bro\conn.log.labeled.csv"

df = pd.read_csv(file_path, delimiter='\t', comment='#', na_values='-', header=None, dtype={'service': str})

# Manually assign column names based on the expected structure
df.columns = [
    'ts', 'uid', 'id.orig_h', 'id.orig_p', 'id.resp_h', 'id.resp_p', 'proto', 'service',
    'duration', 'orig_bytes', 'resp_bytes', 'conn_state', 'local_orig', 'local_resp',
    'missed_bytes', 'history', 'orig_pkts', 'orig_ip_bytes', 'resp_pkts', 'resp_ip_bytes',
    'label'
]

# Check the unique values in the 'label' column
print("Final unique labels:")
print(df['label'].unique())
print("Number of unique labels:", len(df['label'].unique()))
# Out:
# Final unique labels:
# ['-   Benign   -' '-   Malicious   C&C'
#  '-   Malicious   PartOfAHorizontalPortScan' '-   Malicious   DDoS']
# Number of unique labels: 4

# %%
# Step 2: Handle Categorical Variables and Feature Engineering
# Encode label
label_encoder = LabelEncoder()
df['label_encoded'] = label_encoder.fit_transform(df['label'])

# Drop columns that might cause data leakage
df.drop(columns=['uid', 'ts', 'id.orig_h', 'id.resp_h'], inplace=True)

# One-Hot Encode categorical variables
categorical_features = ['proto', 'service', 'conn_state', 'local_orig', 'local_resp', 'history']
df = pd.get_dummies(df, columns=categorical_features, drop_first=True)

# Fill remaining NaN values if any
df.fillna(0, inplace=True)

# Split features and target
X = df.drop(['label', 'label_encoded'], axis=1)
y = df['label_encoded']

# %%
# Step 3: Handle Imbalance using SMOTE
smote = SMOTE()
X_res, y_res = smote.fit_resample(X, y)

# %%
# Step 4: Scale Features
scaler = RobustScaler()
X_res_scaled = scaler.fit_transform(X_res)

# %%
# Step 5: Stratified K-Fold Cross-Validation Setup
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cross_val_scores = []
roc_auc_scores = []
log_losses = []

# Model training and evaluation within each fold
for train_index, val_index in skf.split(X_res_scaled, y_res):
    X_train, X_val = X_res_scaled[train_index], X_res_scaled[val_index]
    y_train, y_val = y_res[train_index], y_res[val_index]

    # Compute class weights
    class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
    class_weights_dict = dict(enumerate(class_weights))

    # Step 6: Build and Compile Model
    model = Sequential([
        Flatten(input_shape=(X_train.shape[1],)),
        Dense(128, activation='relu', kernel_regularizer=l2(0.001)),
        Dropout(0.4),
        Dense(64, activation='relu', kernel_regularizer=l2(0.001)),
        Dropout(0.3),
        Dense(len(np.unique(y_res)), activation='softmax')
    ])

    model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Setup callbacks for early stopping and tensorboard
    log_dir = os.path.join("train_logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
    tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
    early_stop_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Step 7: Model Training
    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, batch_size=256,
              class_weight=class_weights_dict, callbacks=[tensorboard_callback, early_stop_callback])

    # Step 8: Model Evaluation
    val_loss, val_accuracy = model.evaluate(X_val, y_val, verbose=2)
    val_predictions = model.predict(X_val)
    y_pred_classes = np.argmax(val_predictions, axis=1)

    cross_val_scores.append(val_accuracy)
    roc_auc_scores.append(roc_auc_score(y_val, val_predictions, multi_class='ovo'))
    log_losses.append(log_loss(y_val, val_predictions))

    print("Confusion Matrix:")
    print(confusion_matrix(y_val, y_pred_classes))
    print("Classification Report:")
    print(classification_report(y_val, y_pred_classes, target_names=label_encoder.classes_))
# Out:
# Epoch 1/50
# 180/180 [==============================] - 1s 3ms/step - loss: 556.6063 - accuracy: 0.8356 - val_loss: 1.8844 - val_accuracy: 0.9829
# Epoch 2/50
# 180/180 [==============================] - 0s 2ms/step - loss: 355.7767 - accuracy: 0.9336 - val_loss: 1.4159 - val_accuracy: 0.9628
# Epoch 3/50
# 180/180 [==============================] - 1s 3ms/step - loss: 564.4266 - accuracy: 0.9523 - val_loss: 0.8229 - val_accuracy: 0.9872
# Epoch 4/50
# 180/180 [==============================] - 0s 2ms/step - loss: 
# 180/180 [==============================] - 0s 3ms/step - loss: 357.9369 - accuracy: 0.9801 - val_loss: 0.2008 - val_accuracy: 0.9934
# Epoch 42/50
# 180/180 [==============================] - 0s 3ms/step - loss: 57.9599 - accuracy: 0.9839 - val_loss: 0.2211 - val_accuracy: 0.9932
# Epoch 43/50
# 180/180 [==============================] - 0s 3ms/step - loss: 23.5113 - accuracy: 0.9841 - val_loss: 0.2036 - val_accuracy: 0.9933
# Epoch 44/50
# 180/180 [==============================] - 0s 3ms/step - loss: 192.3773 - accuracy: 0.9820 - val_loss: 0.2030 - val_accuracy: 0.9933
# Epoch 45/50
# 180/180 [==============================] - 0s 3ms/step - loss: 91.1063 - accuracy: 0.9827 - val_loss: 0.2063 - val_accuracy: 0.9932
# Epoch 46/50
# 180/180 [==============================] - 0s 3ms/step - loss: 304.5806 - accuracy: 0.9761 - val_loss: 0.2134 - val_accuracy: 0.9713
# Epoch 47/50
# 180/180 [==============================] - 0s 3ms/step - loss: 67.7166 - accuracy: 0.9749 - val_loss: 0.2002 - val_accuracy: 0.9935
# Epoch 48/50
# 180/180 [==============================] - 0s 3ms/step - loss: 23.6117 - accuracy: 0.9817 - val_loss: 0.1939 - val_accuracy: 0.9933
# Epoch 49/50
# 180/180 [==============================] - 0s 2ms/step - loss: 216.8292 - accuracy: 0.9882 - val_loss: 0.2308 - val_accuracy: 0.9932
# Epoch 50/50
# 180/180 [==============================] - 0s 2ms/step - loss: 59.0401 - accuracy: 0.9876 - val_loss: 0.2147 - val_accuracy: 0.9933
# 360/360 - 0s - loss: 0.2147 - accuracy: 0.9933 - 230ms/epoch - 640us/step
# 360/360 [==============================] - 0s 641us/step
# Confusion Matrix:
# [[2834   28    0   17]
#  [   0 2879    0    0]
#  [  29    0 2847    3]
#  [   0    0    0 2879]]
# Classification Report:
#                                            precision    recall  f1-score   support
#
#                            -   Benign   -       0.99      0.98      0.99      2879
#                       -   Malicious   C&C       0.99      1.00      1.00      2879
#                      -   Malicious   DDoS       1.00      0.99      0.99      2879
# -   Malicious   PartOfAHorizontalPortScan       0.99      1.00      1.00      2879
#
#                                  accuracy                           0.99     11516
#                                 macro avg       0.99      0.99      0.99     11516
#                              weighted avg       0.99      0.99      0.99     11516
#
# Epoch 1/50
# 180/180 [==============================] - 1s 3ms/step - loss: 72.0399 - accuracy: 0.8175 - val_loss: 2098.5945 - val_accuracy: 0.9619
# Epoch 2/50
# 180/180 [==============================] - 0s 2ms/step - loss: 8.4216 - accuracy: 0.9231 - val_loss: 3193.0542 - val_accuracy: 0.9634
# Epoch 3/50
# 180/180 [==============================] - 0s 2ms/step - loss: 5.5821 - accuracy: 0.9333 - val_loss: 3358.4639 - val_accuracy: 0.9640
# Epoch 4/50
# 180/180 [==============================] - 0s 2ms/step - loss: 1.8870 - accuracy: 0.9512 - val_loss: 3107.2539 - val_accuracy: 0.9876
# Epoch 5/50
# 180/180 [==============================] - 0s 2ms/step - loss: 4.7400 - accuracy: 0.9587 - val_loss: 2925.0754 - val_accuracy: 0.9878
# Epoch 6/50
# 180/180 [==============================] - 0s 2ms/step - loss: 1.6559 - accuracy: 0.9631 - val_loss: 3144.0552 - val_accuracy: 0.9676
# Epoch 7/50
# 180/180 [==============================] - 0s 2ms/step - loss: 1.0811 - accuracy: 0.9647 - val_loss: 3092.9744 - val_accuracy: 0.9825
# Epoch 8/50
# 180/180 [==============================] - 1s 3ms/step - loss: 4.0359 - accuracy: 0.9609 - val_loss: 3885.0806 - val_accuracy: 0.9739
# Epoch 9/50
# 180/180 [==============================] - 0s 2ms/step - loss: 0.7817 - accuracy: 0.9655 - val_loss: 3795.3699 - val_accuracy: 0.9739
# Epoch 10/50
# 180/180 [==============================] - 0s 2ms/step - loss: 0.7972 - accuracy: 0.9672 - val_loss: 4035.6079 - val_accuracy: 0.9741
# Epoch 11/50
# 180/180 [==============================] - 0s 2ms/step - loss: 0.6933 - accuracy: 0.9664 - val_loss: 4000.1858 - val_accuracy: 0.9741
# 360/360 - 0s - loss: 2098.5950 - accuracy: 0.9619 - 224ms/epoch - 622us/step
# 360/360 [==============================] - 0s 590us/step
# Confusion Matrix:
# [[2468  400    0   11]
#  [   0 2879    0    0]
#  [   1   22 2850    5]
#  [   0    0    0 2879]]
# Classification Report:
#                                            precision    recall  f1-score   support
#
#                            -   Benign   -       1.00      0.86      0.92      2879
#                       -   Malicious   C&C       0.87      1.00      0.93      2879
#                      -   Malicious   DDoS       1.00      0.99      1.00      2878
# -   Malicious   PartOfAHorizontalPortScan       0.99      1.00      1.00      2879
#
#                                  accuracy                           0.96     11515
#                                 macro avg       0.97      0.96      0.96     11515
#                              weighted avg       0.97      0.96      0.96     11515
#
# Epoch 1/50
# 180/180 [==============================] - 1s 3ms/step - loss: 227.6360 - accuracy: 0.8017 - val_loss: 1.8097 - val_accuracy: 0.9428
# Epoch 2/50
# 180/180 [==============================] - 0s 2ms/step - loss: 732.5247 - accuracy: 0.9299 - val_loss: 0.8412 - val_accuracy: 0.9711
# Epoch 3/50
# 180/180 [==============================] - 0s 2ms/step - loss: 301.4300 - accuracy: 0.9405 - val_loss: 0.6070 - val_accuracy: 0.9931
# Epoch 4/50
# 180/180 [==============================] - 0s 2ms/step - loss: 1209.9111 - accuracy: 0.9512 - val_loss: 0.4518 - val_accuracy: 0.9942
# Epoch 5/50
# 180/180 [==============================] - 0s 2ms/step - loss: 573.8576 - accuracy: 0.9514 - val_loss: 0.3877 - val_accuracy: 0.9935
# Epoch 6/50
# 180/180 [==============================] - 0s 2ms/step - loss: 913.2229 - accuracy: 0.9565 - val_loss: 0.3076 - val_accuracy: 0.9947
# Epoch 7/50
# 180/180 [==============================] - 0s 2ms/step - loss: 912.1389 - accuracy: 0.9572 - val_loss: 0.3296 - val_accuracy: 0.9946
# Epoch 8/50
# 180/180 [==============================] - 0s 2ms/step - loss: 968.0341 - accuracy: 0.9627 - val_loss: 0.3233 - val_accuracy: 0.9944
# Epoch 9/50
# 180/180 [==============================] - 0s 2ms/step - loss: 260.4171 - accuracy: 0.9642 - val_loss: 0.2827 - val_accuracy: 0.9949
# Epoch 10/50
# 180/180 [==============================] - 0s 2ms/step - loss: 89.5026 - accuracy: 0.9672 - val_loss: 0.2419 - val_accuracy: 0.9946
# Epoch 11/50
# 180/180 [==============================] - 0s 2ms/step - loss: 7.9879 - accuracy: 0.9723 - val_loss: 0.2367 - val_accuracy: 0.9692
# 360/360 - 0s - loss: 0.1985 - accuracy: 0.9942 - 222ms/epoch - 615us/step
# 360/360 [==============================] - 0s 606us/step
# Confusion Matrix:
# [[2839   25    4   11]
#  [   0 2879    0    0]
#  [  20    0 2858    1]
#  [   6    0    0 2872]]
# Classification Report:
#                                            precision    recall  f1-score   support
#
#                            -   Benign   -       0.99      0.99      0.99      2879
#                       -   Malicious   C&C       0.99      1.00      1.00      2879
#                      -   Malicious   DDoS       1.00      0.99      1.00      2879
# -   Malicious   PartOfAHorizontalPortScan       1.00      1.00      1.00      2878
#
#                                  accuracy                           0.99     11515
#                                 macro avg       0.99      0.99      0.99     11515
#                              weighted avg       0.99      0.99      0.99     11515
#
# Epoch 1/50
# 180/180 [==============================] - 1s 3ms/step - loss: 230.3237 - accuracy: 0.8119 - val_loss: 1.3560 - val_accuracy: 0.9849
# Epoch 2/50
# 180/180 [==============================] - 0s 2ms/step - loss: 546.0992 - accuracy: 0.9337 - val_loss: 0.8719 - val_accuracy: 0.9860
# Epoch 3/50
# 180/180 [==============================] - 0s 2ms/step - loss: 721.8768 - accuracy: 0.9397 - val_loss: 0.5548 - val_accuracy: 0.9880
# Epoch 4/50
# 180/180 [==============================] - 0s 2ms/step - loss: 574.8196 - accuracy: 0.9530 - val_loss: 0.5481 - val_accuracy: 0.9879
# Epoch 5/50
# 180/180 [==============================] - 0s 3ms/step - loss: 433.6400 - accuracy: 0.9602 - val_loss: 0.3277 - val_accuracy: 0.9946
# Epoch 6/50
# 180/180 [==============================] - 0s 2ms/step - loss: 441.0598 - accuracy: 0.9659 - val_loss: 0.3213 - val_accuracy: 0.9945
# Epoch 7/50
# 180/180 [==============================] - 0s 2ms/step - loss: 269.3552 - accuracy: 0.9715 - val_loss: 0.3919 - val_accuracy: 0.9943
# Epoch 8/50
# 180/180 [==============================] - 0s 2ms/step - loss: 477.8084 - accuracy: 0.9690 - val_loss: 0.2656 - val_accuracy: 0.9945
# Epoch 9/50
# 180/180 [==============================] - 0s 2ms/step - loss: 446.9665 - accuracy: 0.9684 - val_loss: 0.2283 - val_accuracy: 0.9950
# Epoch 10/50
# 180/180 [==============================] - 0s 2ms/step - loss: 695.7448 - accuracy: 0.9693 - val_loss: 0.2174 - val_accuracy: 0.9946
# Epoch 11/50
# 180/180 [==============================] - 0s 2ms/step - loss: 564.7064 - accuracy: 0.9646 - val_loss: 0.2182 - val_accuracy: 0.9944
# Epoch 12/50
# 180/180 [==============================] - 0s 2ms/step - loss: 45.3385 - accuracy: 0.9703 - val_loss: 0.2213 - val_accuracy: 0.9945
# Epoch 13/50
# 180/180 [==============================] - 0s 2ms/step - loss: 733.3474 - accuracy: 0.9718 - val_loss: 0.2724 - val_accuracy: 0.9749
# Epoch 14/50
# 180/180 [==============================] - 0s 2ms/step - loss: 41.3440 - accuracy: 0.9713 - val_loss: 0.2211 - val_accuracy: 0.9944
# Epoch 34/50
# 180/180 [==============================] - 0s 2ms/step - loss: 10.4404 - accuracy: 0.9837 - val_loss: 0.4788 - val_accuracy: 0.9922
# Epoch 35/50
# 180/180 [==============================] - 0s 2ms/step - loss: 55.3527 - accuracy: 0.9837 - val_loss: 0.1951 - val_accuracy: 0.9944
# Epoch 36/50
# 180/180 [==============================] - 0s 2ms/step - loss: 8.1779 - accuracy: 0.9855 - val_loss: 0.1902 - val_accuracy: 0.9944
# Epoch 37/50
# 180/180 [==============================] - 0s 2ms/step - loss: 6.4108 - accuracy: 0.9855 - val_loss: 0.1896 - val_accuracy: 0.9944
# Epoch 38/50
# 180/180 [==============================] - 0s 2ms/step - loss: 6.8178 - accuracy: 0.9859 - val_loss: 0.1907 - val_accuracy: 0.9944
# Epoch 39/50
# 180/180 [==============================] - 1s 3ms/step - loss: 121.2322 - accuracy: 0.9831 - val_loss: 0.1957 - val_accuracy: 0.9944
# Epoch 40/50
# 180/180 [==============================] - 0s 2ms/step - loss: 5.5634 - accuracy: 0.9839 - val_loss: 0.1922 - val_accuracy: 0.9945
# Epoch 41/50
# 180/180 [==============================] - 0s 2ms/step - loss: 32.2106 - accuracy: 0.9842 - val_loss: 0.1861 - val_accuracy: 0.9944
# Epoch 42/50
# 180/180 [==============================] - 0s 2ms/step - loss: 36.6488 - accuracy: 0.9851 - val_loss: 0.1802 - val_accuracy: 0.9944
# Epoch 43/50
# 180/180 [==============================] - 0s 2ms/step - loss: 30.1826 - accuracy: 0.9854 - val_loss: 0.1852 - val_accuracy: 0.9944
# Epoch 44/50
# 180/180 [==============================] - 0s 2ms/step - loss: 2.3025 - accuracy: 0.9856 - val_loss: 0.1811 - val_accuracy: 0.9945
# Epoch 45/50
# 180/180 [==============================] - 0s 2ms/step - loss: 1.0149 - accuracy: 0.9862 - val_loss: 0.1795 - val_accuracy: 0.9945
# Epoch 46/50
# 180/180 [==============================] - 0s 2ms/step - loss: 1.4699 - accuracy: 0.9859 - val_loss: 0.1855 - val_accuracy: 0.9944
# Epoch 47/50
# 180/180 [==============================] - 0s 2ms/step - loss: 0.5975 - accuracy: 0.9837 - val_loss: 0.1807 - val_accuracy: 0.9944
# Epoch 48/50
# 180/180 [==============================] - 0s 2ms/step - loss: 0.4260 - accuracy: 0.9868 - val_loss: 0.1770 - val_accuracy: 0.9944
# Epoch 49/50
# 180/180 [==============================] - 0s 2ms/step - loss: 1.4468 - accuracy: 0.9866 - val_loss: 0.1783 - val_accuracy: 0.9944
# Epoch 50/50
# 180/180 [==============================] - 0s 2ms/step - loss: 0.5733 - accuracy: 0.9879 - val_loss: 0.1734 - val_accuracy: 0.9944
# 360/360 - 0s - loss: 0.1734 - accuracy: 0.9944 - 222ms/epoch - 616us/step
# 360/360 [==============================] - 0s 582us/step
# Confusion Matrix:
# [[2836   31    3    9]
#  [   0 2878    0    0]
#  [  20    0 2858    1]
#  [   0    0    0 2879]]
# Classification Report:
#                                            precision    recall  f1-score   support
#
#                            -   Benign   -       0.99      0.99      0.99      2879
#                       -   Malicious   C&C       0.99      1.00      0.99      2878
#                      -   Malicious   DDoS       1.00      0.99      1.00      2879
# -   Malicious   PartOfAHorizontalPortScan       1.00      1.00      1.00      2879
#
#                                  accuracy                           0.99     11515
#                                 macro avg       0.99      0.99      0.99     11515
#                              weighted avg       0.99      0.99      0.99     11515
#
# Epoch 1/50
# Epoch 39/50
# 180/180 [==============================] - 0s 3ms/step - loss: 8.4029 - accuracy: 0.9836 - val_loss: 0.1709 - val_accuracy: 0.9944
# Epoch 40/50
# 180/180 [==============================] - 0s 3ms/step - loss: 46.1065 - accuracy: 0.9833 - val_loss: 0.1665 - val_accuracy: 0.9945
# Epoch 41/50
# 180/180 [==============================] - 0s 3ms/step - loss: 9.2554 - accuracy: 0.9813 - val_loss: 0.1678 - val_accuracy: 0.9944
# Epoch 42/50
# 180/180 [==============================] - 1s 3ms/step - loss: 25.3955 - accuracy: 0.9808 - val_loss: 2.4797 - val_accuracy: 0.9918
# Epoch 43/50
# 180/180 [==============================] - 0s 3ms/step - loss: 11.6480 - accuracy: 0.9805 - val_loss: 0.1660 - val_accuracy: 0.9943
# Epoch 44/50
# 180/180 [==============================] - 0s 3ms/step - loss: 12.6798 - accuracy: 0.9799 - val_loss: 0.1642 - val_accuracy: 0.9945
# Epoch 45/50
# 180/180 [==============================] - 0s 3ms/step - loss: 2.5429 - accuracy: 0.9823 - val_loss: 0.1651 - val_accuracy: 0.9944
# Epoch 46/50
# 180/180 [==============================] - 0s 3ms/step - loss: 13.0420 - accuracy: 0.9827 - val_loss: 1.9319 - val_accuracy: 0.9879
# Epoch 47/50
# 180/180 [==============================] - 0s 3ms/step - loss: 2.2890 - accuracy: 0.9835 - val_loss: 0.1616 - val_accuracy: 0.9944
# Epoch 48/50
# 180/180 [==============================] - 0s 3ms/step - loss: 12.8724 - accuracy: 0.9846 - val_loss: 0.1598 - val_accuracy: 0.9944
# Epoch 49/50
# 180/180 [==============================] - 0s 3ms/step - loss: 39.2357 - accuracy: 0.9856 - val_loss: 0.1574 - val_accuracy: 0.9946
# Epoch 50/50
# 180/180 [==============================] - 0s 3ms/step - loss: 14.5505 - accuracy: 0.9777 - val_loss: 0.1815 - val_accuracy: 0.9919
# 360/360 - 0s - loss: 0.1815 - accuracy: 0.9919 - 227ms/epoch - 631us/step
# 360/360 [==============================] - 0s 601us/step
# Confusion Matrix:
# [[2837   36    1    4]
#  [   0 2879    0    0]
#  [  21    1 2855    2]
#  [  19    9    0 2851]]
# Classification Report:
#                                            precision    recall  f1-score   support
#
#                            -   Benign   -       0.99      0.99      0.99      2878
#                       -   Malicious   C&C       0.98      1.00      0.99      2879
#                      -   Malicious   DDoS       1.00      0.99      1.00      2879
# -   Malicious   PartOfAHorizontalPortScan       1.00      0.99      0.99      2879
#
#                                  accuracy                           0.99     11515
#                                 macro avg       0.99      0.99      0.99     11515
#                              weighted avg       0.99      0.99      0.99     11515

# %%
# Step 9: Summary of Cross-Validation Results
print(f"Mean CV Accuracy: {np.mean(cross_val_scores)}")
print(f"Mean ROC-AUC Score: {np.mean(roc_auc_scores)}")
print(f"Mean Log Loss: {np.mean(log_losses)}")
# Out:
# Mean CV Accuracy: 0.9871473193168641
# Mean ROC-AUC Score: 0.9932508252323821
# Mean Log Loss: 0.1373002624623973
